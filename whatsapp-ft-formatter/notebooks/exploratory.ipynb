# %% [markdown]
# # Exploratory Data Analysis & Experimentation
#
# This notebook can be used for:
#
# - Testing parsing logic with different chat examples.
# - Visualizing message distributions.
# - Experimenting with segmentation parameters (e.g., timeout, semantic similarity thresholds).
# - Evaluating NLP entity extraction quality.
# - Prototyping new features.

# %%
# Example: Load and parse a sample chat file
import os
from src import parser
from config import settings

sample_file = os.path.join(settings.RAW_DATA_DIR, "sample.txt")

if os.path.exists(sample_file):
    messages = parser.parse_txt([sample_file])
    print(f"Parsed {len(messages)} messages from {sample_file}.")
    # for msg in messages[:5]:
    #     print(msg)
else:
    print(f"Sample file not found at {sample_file}")

# %% [markdown]
# ## Segmentation Experiments

# %%
# from src import segmentation
# 
# if 'messages' in locals() and messages:
#     # settings.TIMEOUT_MINUTES = 3 # Example: override for experiment
#     # settings.SEMANTIC_SIMILARITY_THRESHOLD = 0.6 # Example: override
#     conversations = segmentation.segment(messages)
#     print(f"Segmented into {len(conversations)} conversations.")
#     # for i, conv in enumerate(conversations):
#     #     print(f"Conversation {i+1}: {len(conv)} messages")
